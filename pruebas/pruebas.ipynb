# %%
import pandas as pd
import numpy as np
import re

# %%
from pymongo import MongoClient

client = MongoClient()

def connectCollection(database, collection):
    ''' return collection from db crunchbase'''
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('dbcompanies','companies')

# %%
# Primer filtro:
filter1 = [
    {"$match": {"$and":
            [{"founded_year": {"$gte": 2009}}, # Fundadas a partir del 2009
             {"deadpooled_year": None}, # Que no hayan quebrado
             {"offices.latitude": {"$exists": True, "$ne": None}}, # Que tengan latitud
             {"offices.longitude": {"$exists": True, "$ne": None}}]}}] # Que tengan longitud

# %%
offices = list(coll.aggregate(filter1))

# %%
def prepareData(bd):
    cleanedItems = []
    errors = 0
    for group in offices:
        for item in range(len(group['offices'])):
            try:
                cleanedItems.append({
                "name":group["name"],
                "employees": group['number_of_employees'],
                "year":group['founded_year'],
                "category":group['category_code'],
                "id":group['_id'],
                "money raised":group['total_money_raised'],
                "city" : group['offices'][item]['city'],
                "country" : group['offices'][item]['country_code'],
                "latitude" : group['offices'][item]['latitude'],
                "longitude" : group['offices'][item]['longitude'],
                "coordinates":{
                    "type":"Point",
                    "coordinates":[group['offices'][item]['longitude'],group['offices'][item]['latitude']]}})
            except Exception:
                errors += 1
                if errors > 0:
                    print(f"Hay {errors} errores")
    return cleanedItems

# %%
prepareData(offices)
# Out:
# [{'name': 'Mokitown',
#   'employees': None,
#   'year': 2011,
#   'category': 'web',
#   'id': ObjectId('52cdef7c4bab8bd675297ea7'),
#   'money raised': '$0',
#   'city': None,
#   'country': 'USA',
#   'latitude': 37.09024,
#   'longitude': -95.712891,
#   'coordinates': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'name': 'PeekYou',
#   'employees': 20,
#   'year': 2012,
#   'category': 'search',
#   'id': ObjectId('52cdef7c4bab8bd675297f94'),
#   'money raised': '$1.83M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.757929,
#   'longitude': -73.985506,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]}},
#  {'name': 'GENWI',
#   'employees': 25,
#   'year': 2010,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7c4bab8bd675297f9e'),
#   'money raised': '$7.1M',
#   'city': 'Los Altos',
#   'country': 'USA',
#   'latitude': 33.8171,
#   'longitude': -111.9035,
#   'coordinates': {'type': 'Point', 'coordinates': [-111.9035, 33.8171]}},
#  {'name': 'Fixya',
#   'employees': 30,
#   'year': 2013,
#   'category': 'web',
#   'id': ObjectId('52cdef7c4bab8bd675297fec'),
#   'money raised': '$8M',
#   'city': 'San Mateo',
#   'country': 'USA',
#   'latitude': 37.566879,
#   'longitude': -122.323895,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.323895, 37.566879]}},
#  {'name': 'alluc',
#   'employees': 7,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7c4bab8bd675298038'),
#   'money raised': '$0',
#   'city': 'Norderstedt',
#   'country': 'DEU',
#   'latitude': 53.707739,
#   'longitude': 10.023246,
#   'coordinates': {'type': 'Point', 'coordinates': [10.023246, 53.707739]}},
#  {'name': 'Widgetbox',
#   'employees': 30,
#   'year': 2012,
#   'category': 'other',
#   'id': ObjectId('52cdef7c4bab8bd6752981d8'),
#   'money raised': '$14.5M',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.798853,
#   'longitude': -122.398599,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.398599, 37.798853]}},
#  {'name': 'RazorGator',
#   'employees': None,
#   'year': 2011,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7c4bab8bd6752981dc'),
#   'money raised': '$58.8M',
#   'city': 'Los Angeles',
#   'country': 'USA',
#   'latitude': 34.047312,
#   'longitude': -118.445243,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.445243, 34.047312]}},
#  {'name': 'Fluc',
#   'employees': 3,
#   'year': 2013,
#   'category': 'hospitality',
#   'id': ObjectId('52cdef7c4bab8bd67529830a'),
#   'money raised': '$0',
#   'city': 'Menlo Park',
#   'country': 'USA',
#   'latitude': 37.454701,
#   'longitude': -122.1853756,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.1853756, 37.454701]}},
#  {'name': 'Social Gaming Network',
#   'employees': 100,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7c4bab8bd67529831a'),
#   'money raised': '$17.1M',
#   'city': 'Los Angeles',
#   'country': 'USA',
#   'latitude': 37.446823,
#   'longitude': -122.161523,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.161523, 37.446823]}},
#  {'name': 'Social Gaming Network',
#   'employees': 100,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7c4bab8bd67529831a'),
#   'money raised': '$17.1M',
#   'city': 'Beverly Hills',
#   'country': 'USA',
#   'latitude': 34.0698494,
#   'longitude': -118.4054182,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.4054182, 34.0698494]}},
#  {'name': 'YouNoodle',
#   'employees': 18,
#   'year': 2010,
#   'category': 'analytics',
#   'id': ObjectId('52cdef7c4bab8bd675298347'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.7766587,
#   'longitude': -122.395875,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.395875, 37.7766587]}},
#  {'name': 'Crootpad',
#   'employees': 2,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7c4bab8bd6752984f4'),
#   'money raised': '$0',
#   'city': 'West Dundee',
#   'country': 'USA',
#   'latitude': 42.091078,
#   'longitude': -88.288749,
#   'coordinates': {'type': 'Point', 'coordinates': [-88.288749, 42.091078]}},
#  {'name': 'Skydeck',
#   'employees': 9,
#   'year': 2012,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7c4bab8bd675298509'),
#   'money raised': '$4M',
#   'city': 'Palo Alto',
#   'country': 'USA',
#   'latitude': 37.5645375,
#   'longitude': -122.3254705,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.3254705, 37.5645375]}},
#  {'name': 'Ninite',
#   'employees': 2,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7c4bab8bd675298555'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.789349,
#   'longitude': -122.412893,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.412893, 37.789349]}},
#  {'name': 'Handipoints',
#   'employees': None,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7c4bab8bd675298591'),
#   'money raised': '$800k',
#   'city': 'Oakland',
#   'country': 'USA',
#   'latitude': 37.772323,
#   'longitude': -122.214897,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.214897, 37.772323]}},
#  {'name': 'Magento',
#   'employees': 275,
#   'year': 2010,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7c4bab8bd675298608'),
#   'money raised': '$22.5M',
#   'city': 'Los Angeles',
#   'country': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'name': 'Macroaxis',
#   'employees': 8,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7c4bab8bd67529886d'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.7896292,
#   'longitude': -122.3998782,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.3998782, 37.7896292]}},
#  {'name': 'Jumbuck Entertainment',
#   'employees': None,
#   'year': 2012,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7d4bab8bd67529894b'),
#   'money raised': '$0',
#   'city': 'Melbourne',
#   'country': 'AUS',
#   'latitude': -37.817748,
#   'longitude': 144.962991,
#   'coordinates': {'type': 'Point', 'coordinates': [144.962991, -37.817748]}},
#  {'name': 'Pixsta',
#   'employees': None,
#   'year': 2010,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675298970'),
#   'money raised': '£3M',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.51819,
#   'longitude': -0.208979,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.208979, 51.51819]}},
#  {'name': 'FirstString',
#   'employees': None,
#   'year': 2011,
#   'category': 'search',
#   'id': ObjectId('52cdef7d4bab8bd6752989f3'),
#   'money raised': '$200k',
#   'city': 'Los Angeles',
#   'country': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'name': 'Fuzz',
#   'employees': 6,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675298a4d'),
#   'money raised': '$0',
#   'city': 'Santa Clara',
#   'country': 'USA',
#   'latitude': 37.760524,
#   'longitude': -122.387799,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.387799, 37.760524]}},
#  {'name': 'BrandYourself',
#   'employees': 22,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675298ce2'),
#   'money raised': '$1.5M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 42.275263,
#   'longitude': -71.24762,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.24762, 42.275263]}},
#  {'name': 'CollegeConvo',
#   'employees': 2,
#   'year': 2010,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675298cff'),
#   'money raised': '$0',
#   'city': 'Van Nuys',
#   'country': 'USA',
#   'latitude': 40.650291,
#   'longitude': -74.294395,
#   'coordinates': {'type': 'Point', 'coordinates': [-74.294395, 40.650291]}},
#  {'name': 'Carfeine',
#   'employees': 5,
#   'year': 2012,
#   'category': 'software',
#   'id': ObjectId('52cdef7d4bab8bd675298da5'),
#   'money raised': '$0',
#   'city': 'Bethesda',
#   'country': 'USA',
#   'latitude': 38.989124,
#   'longitude': -77.026676,
#   'coordinates': {'type': 'Point', 'coordinates': [-77.026676, 38.989124]}},
#  {'name': 'Ziippi',
#   'employees': 6,
#   'year': 2011,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675298dba'),
#   'money raised': '$0',
#   'city': 'Palo Alto',
#   'country': 'USA',
#   'latitude': 37.4440981,
#   'longitude': -122.1612868,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.1612868, 37.4440981]}},
#  {'name': 'Vusion',
#   'employees': None,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675298dc1'),
#   'money raised': '$0',
#   'city': 'Milpitas',
#   'country': 'USA',
#   'latitude': 37.412069,
#   'longitude': -121.900366,
#   'coordinates': {'type': 'Point', 'coordinates': [-121.900366, 37.412069]}},
#  {'name': 'Titan Gaming',
#   'employees': 18,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675298dcc'),
#   'money raised': '$1M',
#   'city': 'Santa Monica',
#   'country': 'USA',
#   'latitude': 53.544711,
#   'longitude': -113.515769,
#   'coordinates': {'type': 'Point', 'coordinates': [-113.515769, 53.544711]}},
#  {'name': 'BitRock',
#   'employees': 20,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7d4bab8bd675298eb1'),
#   'money raised': '$0',
#   'city': 'Alameda',
#   'country': 'USA',
#   'latitude': 37.78424,
#   'longitude': -122.274771,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.274771, 37.78424]}},
#  {'name': 'JumpForward',
#   'employees': 30,
#   'year': 2010,
#   'category': 'software',
#   'id': ObjectId('52cdef7d4bab8bd675298fd5'),
#   'money raised': '$0',
#   'city': 'Chicago',
#   'country': 'USA',
#   'latitude': 41.857204,
#   'longitude': -87.623923,
#   'coordinates': {'type': 'Point', 'coordinates': [-87.623923, 41.857204]}},
#  {'name': 'Gimigo',
#   'employees': 4,
#   'year': 2013,
#   'category': 'analytics',
#   'id': ObjectId('52cdef7d4bab8bd675298fe1'),
#   'money raised': '$0',
#   'city': 'Seattle',
#   'country': 'USA',
#   'latitude': 44.859587,
#   'longitude': -93.226503,
#   'coordinates': {'type': 'Point', 'coordinates': [-93.226503, 44.859587]}},
#  {'name': 'OTOY',
#   'employees': None,
#   'year': 2010,
#   'category': 'software',
#   'id': ObjectId('52cdef7d4bab8bd675299115'),
#   'money raised': '$0',
#   'city': 'Sherman Oaks',
#   'country': 'USA',
#   'latitude': 34.15761,
#   'longitude': -118.424058,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.424058, 34.15761]}},
#  {'name': 'N-Play',
#   'employees': 25,
#   'year': 2011,
#   'category': 'social',
#   'id': ObjectId('52cdef7d4bab8bd6752991fa'),
#   'money raised': '$0',
#   'city': 'Jacksonville',
#   'country': 'USA',
#   'latitude': 30.26955,
#   'longitude': -81.564709,
#   'coordinates': {'type': 'Point', 'coordinates': [-81.564709, 30.26955]}},
#  {'name': 'SEOGroup',
#   'employees': 3,
#   'year': 2013,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd675299291'),
#   'money raised': '$0',
#   'city': 'Chicago',
#   'country': 'USA',
#   'latitude': 41.886264,
#   'longitude': -87.624701,
#   'coordinates': {'type': 'Point', 'coordinates': [-87.624701, 41.886264]}},
#  {'name': 'CompareAway',
#   'employees': 5,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675299444'),
#   'money raised': '£500k',
#   'city': 'Durham',
#   'country': 'GBR',
#   'latitude': 54.703145,
#   'longitude': -1.574948,
#   'coordinates': {'type': 'Point', 'coordinates': [-1.574948, 54.703145]}},
#  {'name': 'vufind',
#   'employees': 7,
#   'year': 2010,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7d4bab8bd6752995d0'),
#   'money raised': '$930k',
#   'city': 'Sunnyvale',
#   'country': 'USA',
#   'latitude': 37.424614,
#   'longitude': -122.145153,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.145153, 37.424614]}},
#  {'name': 'travelmob',
#   'employees': 4,
#   'year': 2011,
#   'category': 'travel',
#   'id': ObjectId('52cdef7d4bab8bd6752995ff'),
#   'money raised': '$1M',
#   'city': 'Singapore',
#   'country': 'SGP',
#   'latitude': 21.303049,
#   'longitude': -157.78907,
#   'coordinates': {'type': 'Point', 'coordinates': [-157.78907, 21.303049]}},
#  {'name': 'Non-Member Films',
#   'employees': None,
#   'year': 2012,
#   'category': 'photo_video',
#   'id': ObjectId('52cdef7d4bab8bd675299609'),
#   'money raised': '$0',
#   'city': 'Venice',
#   'country': 'USA',
#   'latitude': 33.989029,
#   'longitude': -118.462421,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.462421, 33.989029]}},
#  {'name': 'Non-Member Films',
#   'employees': None,
#   'year': 2012,
#   'category': 'photo_video',
#   'id': ObjectId('52cdef7d4bab8bd675299609'),
#   'money raised': '$0',
#   'city': 'Detroit',
#   'country': 'USA',
#   'latitude': 42.330165,
#   'longitude': -83.045913,
#   'coordinates': {'type': 'Point', 'coordinates': [-83.045913, 42.330165]}},
#  {'name': 'UsingMiles',
#   'employees': 15,
#   'year': 2010,
#   'category': 'travel',
#   'id': ObjectId('52cdef7d4bab8bd675299636'),
#   'money raised': '$3.27M',
#   'city': 'Denver',
#   'country': 'USA',
#   'latitude': 39.749671,
#   'longitude': -104.9998449,
#   'coordinates': {'type': 'Point', 'coordinates': [-104.9998449, 39.749671]}},
#  {'name': 'Burt',
#   'employees': 30,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd6752996f5'),
#   'money raised': '$3.5M',
#   'city': 'Gothenburg',
#   'country': 'SWE',
#   'latitude': 59.337864,
#   'longitude': 18.036587,
#   'coordinates': {'type': 'Point', 'coordinates': [18.036587, 59.337864]}},
#  {'name': 'Inuvo',
#   'employees': 50,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd67529980b'),
#   'money raised': '$4.2M',
#   'city': 'Clearwater',
#   'country': 'USA',
#   'latitude': 27.913011,
#   'longitude': -82.702449,
#   'coordinates': {'type': 'Point', 'coordinates': [-82.702449, 27.913011]}},
#  {'name': 'Kidos',
#   'employees': None,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675299826'),
#   'money raised': '$200k',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.768058,
#   'longitude': -73.956599,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.956599, 40.768058]}},
#  {'name': 'Kidos',
#   'employees': None,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675299826'),
#   'money raised': '$200k',
#   'city': 'Brooklyn',
#   'country': 'USA',
#   'latitude': 40.714056,
#   'longitude': -73.957854,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.957854, 40.714056]}},
#  {'name': 'vufind',
#   'employees': 7,
#   'year': 2010,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7d4bab8bd67529995a'),
#   'money raised': '$930k',
#   'city': 'Sunnyvale',
#   'country': 'USA',
#   'latitude': 37.424614,
#   'longitude': -122.145153,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.145153, 37.424614]}},
#  {'name': 'travelmob',
#   'employees': 4,
#   'year': 2011,
#   'category': 'travel',
#   'id': ObjectId('52cdef7d4bab8bd675299989'),
#   'money raised': '$1M',
#   'city': 'Singapore',
#   'country': 'SGP',
#   'latitude': 21.303049,
#   'longitude': -157.78907,
#   'coordinates': {'type': 'Point', 'coordinates': [-157.78907, 21.303049]}},
#  {'name': 'Non-Member Films',
#   'employees': None,
#   'year': 2012,
#   'category': 'photo_video',
#   'id': ObjectId('52cdef7d4bab8bd675299993'),
#   'money raised': '$0',
#   'city': 'Venice',
#   'country': 'USA',
#   'latitude': 33.989029,
#   'longitude': -118.462421,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.462421, 33.989029]}},
#  {'name': 'Non-Member Films',
#   'employees': None,
#   'year': 2012,
#   'category': 'photo_video',
#   'id': ObjectId('52cdef7d4bab8bd675299993'),
#   'money raised': '$0',
#   'city': 'Detroit',
#   'country': 'USA',
#   'latitude': 42.330165,
#   'longitude': -83.045913,
#   'coordinates': {'type': 'Point', 'coordinates': [-83.045913, 42.330165]}},
#  {'name': 'UsingMiles',
#   'employees': 15,
#   'year': 2010,
#   'category': 'travel',
#   'id': ObjectId('52cdef7d4bab8bd6752999c0'),
#   'money raised': '$3.27M',
#   'city': 'Denver',
#   'country': 'USA',
#   'latitude': 39.749671,
#   'longitude': -104.9998449,
#   'coordinates': {'type': 'Point', 'coordinates': [-104.9998449, 39.749671]}},
#  {'name': 'Burt',
#   'employees': 30,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd675299a7f'),
#   'money raised': '$3.5M',
#   'city': 'Gothenburg',
#   'country': 'SWE',
#   'latitude': 59.337864,
#   'longitude': 18.036587,
#   'coordinates': {'type': 'Point', 'coordinates': [18.036587, 59.337864]}},
#  {'name': 'Inuvo',
#   'employees': 50,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd675299b95'),
#   'money raised': '$4.2M',
#   'city': 'Clearwater',
#   'country': 'USA',
#   'latitude': 27.913011,
#   'longitude': -82.702449,
#   'coordinates': {'type': 'Point', 'coordinates': [-82.702449, 27.913011]}},
#  {'name': 'Kidos',
#   'employees': None,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675299bb0'),
#   'money raised': '$200k',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.768058,
#   'longitude': -73.956599,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.956599, 40.768058]}},
#  {'name': 'Kidos',
#   'employees': None,
#   'year': 2011,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675299bb0'),
#   'money raised': '$200k',
#   'city': 'Brooklyn',
#   'country': 'USA',
#   'latitude': 40.714056,
#   'longitude': -73.957854,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.957854, 40.714056]}},
#  {'name': 'Magoosh',
#   'employees': 13,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd675299c72'),
#   'money raised': '$0',
#   'city': 'Berkeley',
#   'country': 'USA',
#   'latitude': 37.871087,
#   'longitude': -122.270913,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.270913, 37.871087]}},
#  {'name': 'Equedia',
#   'employees': None,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7d4bab8bd675299d93'),
#   'money raised': '$0',
#   'city': 'Vancouver',
#   'country': 'CAN',
#   'latitude': 49.2871668,
#   'longitude': -123.1169693,
#   'coordinates': {'type': 'Point', 'coordinates': [-123.1169693, 49.2871668]}},
#  {'name': 'Navara',
#   'employees': 80,
#   'year': 2012,
#   'category': 'software',
#   'id': ObjectId('52cdef7d4bab8bd675299dae'),
#   'money raised': '$0',
#   'city': 'Maarssen',
#   'country': 'NLD',
#   'latitude': 52.126616,
#   'longitude': 5.038078,
#   'coordinates': {'type': 'Point', 'coordinates': [5.038078, 52.126616]}},
#  {'name': 'Webmoblink',
#   'employees': 7,
#   'year': 2010,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd675299f83'),
#   'money raised': '$0',
#   'city': 'Miami',
#   'country': 'USA',
#   'latitude': 25.655899,
#   'longitude': -80.424167,
#   'coordinates': {'type': 'Point', 'coordinates': [-80.424167, 25.655899]}},
#  {'name': 'Formspring',
#   'employees': 19,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd67529a00e'),
#   'money raised': '$14.3M',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 39.9052263,
#   'longitude': -86.0547016,
#   'coordinates': {'type': 'Point', 'coordinates': [-86.0547016, 39.9052263]}},
#  {'name': 'isocket',
#   'employees': None,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7d4bab8bd67529a08a'),
#   'money raised': '$10.1M',
#   'city': 'Burlingame',
#   'country': 'USA',
#   'latitude': 37.55909,
#   'longitude': -122.321836,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.321836, 37.55909]}},
#  {'name': 'Yipit',
#   'employees': 23,
#   'year': 2010,
#   'category': 'web',
#   'id': ObjectId('52cdef7d4bab8bd67529a1e3'),
#   'money raised': '$7.55M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.744618,
#   'longitude': -73.987764,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.987764, 40.744618]}},
#  {'name': 'StudyBlue',
#   'employees': 18,
#   'year': 2009,
#   'category': 'education',
#   'id': ObjectId('52cdef7e4bab8bd67529a29f'),
#   'money raised': '$18.5M',
#   'city': 'Madison',
#   'country': 'USA',
#   'latitude': 43.068006,
#   'longitude': -89.39256,
#   'coordinates': {'type': 'Point', 'coordinates': [-89.39256, 43.068006]}},
#  {'name': 'fruux',
#   'employees': None,
#   'year': 2010,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529a2d5'),
#   'money raised': '$0',
#   'city': 'Muenster',
#   'country': 'DEU',
#   'latitude': 51.9630088,
#   'longitude': 7.6267552,
#   'coordinates': {'type': 'Point', 'coordinates': [7.6267552, 51.9630088]}},
#  {'name': 'Cyphercor',
#   'employees': 3,
#   'year': 2011,
#   'category': 'security',
#   'id': ObjectId('52cdef7e4bab8bd67529a38a'),
#   'money raised': '$0',
#   'city': 'Kanata',
#   'country': 'CAN',
#   'latitude': 45.3485325,
#   'longitude': -75.9204125,
#   'coordinates': {'type': 'Point', 'coordinates': [-75.9204125, 45.3485325]}},
#  {'name': 'Clowdy',
#   'employees': 11,
#   'year': 2013,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529a3b8'),
#   'money raised': '$0',
#   'city': 'Manchester',
#   'country': 'GBR',
#   'latitude': 53.4837067,
#   'longitude': -2.2439492,
#   'coordinates': {'type': 'Point', 'coordinates': [-2.2439492, 53.4837067]}},
#  {'name': 'Carsala',
#   'employees': 8,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529a471'),
#   'money raised': '$0',
#   'city': 'Berkeley',
#   'country': 'USA',
#   'latitude': 37.870457,
#   'longitude': -122.268354,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.268354, 37.870457]}},
#  {'name': 'HyperWeek',
#   'employees': 5,
#   'year': 2009,
#   'category': 'social',
#   'id': ObjectId('52cdef7e4bab8bd67529a4b2'),
#   'money raised': '$1.31M',
#   'city': 'Geneva',
#   'country': 'CHE',
#   'latitude': 46.2121463,
#   'longitude': 6.1503245,
#   'coordinates': {'type': 'Point', 'coordinates': [6.1503245, 46.2121463]}},
#  {'name': 'LaunchPad Coworking',
#   'employees': 6,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7e4bab8bd67529a4d8'),
#   'money raised': '$0',
#   'city': 'Austin',
#   'country': 'USA',
#   'latitude': 30.269967,
#   'longitude': -97.740833,
#   'coordinates': {'type': 'Point', 'coordinates': [-97.740833, 30.269967]}},
#  {'name': 'Queralt',
#   'employees': 7,
#   'year': 2011,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529a532'),
#   'money raised': '$650k',
#   'city': 'North Haven',
#   'country': 'USA',
#   'latitude': 41.4778641,
#   'longitude': -72.8190106,
#   'coordinates': {'type': 'Point', 'coordinates': [-72.8190106, 41.4778641]}},
#  {'name': 'Social1000',
#   'employees': 1,
#   'year': 2009,
#   'category': 'network_hosting',
#   'id': ObjectId('52cdef7e4bab8bd67529a6e9'),
#   'money raised': '$0',
#   'city': 'Seattle',
#   'country': 'USA',
#   'latitude': 61.216583,
#   'longitude': -149.899597,
#   'coordinates': {'type': 'Point', 'coordinates': [-149.899597, 61.216583]}},
#  {'name': 'Unison Technologies',
#   'employees': 30,
#   'year': 2011,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529a716'),
#   'money raised': '$0',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.7645772,
#   'longitude': -73.9799007,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9799007, 40.7645772]}},
#  {'name': 'NetCitadel',
#   'employees': 25,
#   'year': 2011,
#   'category': 'security',
#   'id': ObjectId('52cdef7e4bab8bd67529a72a'),
#   'money raised': '$0',
#   'city': 'Mountain View',
#   'country': 'USA',
#   'latitude': 44.867343,
#   'longitude': -72.114442,
#   'coordinates': {'type': 'Point', 'coordinates': [-72.114442, 44.867343]}},
#  {'name': 'Jolicloud',
#   'employees': None,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529a73a'),
#   'money raised': '$4.2M',
#   'city': 'Paris',
#   'country': 'FRA',
#   'latitude': 48.8566667,
#   'longitude': 2.3509871,
#   'coordinates': {'type': 'Point', 'coordinates': [2.3509871, 48.8566667]}},
#  {'name': 'Tengaged',
#   'employees': 1,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529a75f'),
#   'money raised': '$15k',
#   'city': 'Barcelona',
#   'country': 'ESP',
#   'latitude': 41.4241228,
#   'longitude': 2.1634249,
#   'coordinates': {'type': 'Point', 'coordinates': [2.1634249, 41.4241228]}},
#  {'name': 'Reachoo',
#   'employees': 3,
#   'year': 2010,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529a805'),
#   'money raised': '$0',
#   'city': 'Pompano Beach',
#   'country': 'USA',
#   'latitude': 26.2480738,
#   'longitude': -80.135487,
#   'coordinates': {'type': 'Point', 'coordinates': [-80.135487, 26.2480738]}},
#  {'name': 'Indee',
#   'employees': 3,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529a872'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.8053241,
#   'longitude': -122.4052761,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.4052761, 37.8053241]}},
#  {'name': 'LoveAccess',
#   'employees': None,
#   'year': 2012,
#   'category': 'other',
#   'id': ObjectId('52cdef7e4bab8bd67529a8ca'),
#   'money raised': '$0',
#   'city': 'Norwell',
#   'country': 'USA',
#   'latitude': 42.166398,
#   'longitude': -70.884948,
#   'coordinates': {'type': 'Point', 'coordinates': [-70.884948, 42.166398]}},
#  {'name': 'GymFu',
#   'employees': 3,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529aa47'),
#   'money raised': '$0',
#   'city': 'Ringwood, Hampshire',
#   'country': 'GBR',
#   'latitude': 50.841938,
#   'longitude': -1.7884785,
#   'coordinates': {'type': 'Point', 'coordinates': [-1.7884785, 50.841938]}},
#  {'name': 'Do You Wanna Hook Up?',
#   'employees': 3,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529aa48'),
#   'money raised': '$0',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.5889016,
#   'longitude': -73.9447994,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9447994, 40.5889016]}},
#  {'name': 'Wappalyzer',
#   'employees': None,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529aa7d'),
#   'money raised': '$0',
#   'city': 'Rotterdam',
#   'country': 'NLD',
#   'latitude': 52.3624655,
#   'longitude': 5.2025569,
#   'coordinates': {'type': 'Point', 'coordinates': [5.2025569, 52.3624655]}},
#  {'name': 'facelovefinder',
#   'employees': 1,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529aaa9'),
#   'money raised': '$0',
#   'city': 'Torreon, Coahuila',
#   'country': 'MEX',
#   'latitude': 25.5230058,
#   'longitude': -103.4174464,
#   'coordinates': {'type': 'Point', 'coordinates': [-103.4174464, 25.5230058]}},
#  {'name': 'Infor',
#   'employees': None,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529aabe'),
#   'money raised': '$0',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.740976,
#   'longitude': -73.9947229,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9947229, 40.740976]}},
#  {'name': 'eCampusCash',
#   'employees': 3,
#   'year': 2010,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529aae4'),
#   'money raised': '$0',
#   'city': 'Van Nuys',
#   'country': 'USA',
#   'latitude': 40.650291,
#   'longitude': -74.294395,
#   'coordinates': {'type': 'Point', 'coordinates': [-74.294395, 40.650291]}},
#  {'name': 'ScaleMP',
#   'employees': None,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529ab2f'),
#   'money raised': '$8M',
#   'city': 'Cupertino',
#   'country': 'USA',
#   'latitude': 37.3229727,
#   'longitude': -122.0385792,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.0385792, 37.3229727]}},
#  {'name': 'Otalo',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529ab61'),
#   'money raised': '$0',
#   'city': 'Amherst',
#   'country': 'USA',
#   'latitude': 42.3756007,
#   'longitude': -72.4436464,
#   'coordinates': {'type': 'Point', 'coordinates': [-72.4436464, 42.3756007]}},
#  {'name': 'Digital Meld',
#   'employees': 5,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529abab'),
#   'money raised': '$0',
#   'city': 'Houston',
#   'country': 'USA',
#   'latitude': 29.714229,
#   'longitude': -95.527479,
#   'coordinates': {'type': 'Point', 'coordinates': [-95.527479, 29.714229]}},
#  {'name': 'VisualOn',
#   'employees': None,
#   'year': 2011,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529abc2'),
#   'money raised': '$3.1M',
#   'city': 'Santa Clara',
#   'country': 'USA',
#   'latitude': 37.270518,
#   'longitude': -121.955879,
#   'coordinates': {'type': 'Point', 'coordinates': [-121.955879, 37.270518]}},
#  {'name': 'Twtapps',
#   'employees': 1,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529abd5'),
#   'money raised': '$0',
#   'city': 'Montreal',
#   'country': 'CAN',
#   'latitude': 45.4928591,
#   'longitude': -73.5825418,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.5825418, 45.4928591]}},
#  {'name': 'Heyzap',
#   'employees': None,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529abd9'),
#   'money raised': '$7.97M',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.7905538,
#   'longitude': -122.4041485,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.4041485, 37.7905538]}},
#  {'name': 'Talk to a Celeb',
#   'employees': 5,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7e4bab8bd67529abf5'),
#   'money raised': '$0',
#   'city': 'Santa Barbara',
#   'country': 'USA',
#   'latitude': 34.423403,
#   'longitude': -119.704416,
#   'coordinates': {'type': 'Point', 'coordinates': [-119.704416, 34.423403]}},
#  {'name': 'iShopWiser',
#   'employees': 2,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7e4bab8bd67529abf3'),
#   'money raised': '$0',
#   'city': 'Westford',
#   'country': 'USA',
#   'latitude': 42.610112,
#   'longitude': -71.442225,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.442225, 42.610112]}},
#  {'name': 'Meez',
#   'employees': 21,
#   'year': 2009,
#   'category': 'hardware',
#   'id': ObjectId('52cdef7e4bab8bd67529ac2f'),
#   'money raised': '$10.2M',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.785271,
#   'longitude': -122.397582,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.397582, 37.785271]}},
#  {'name': 'About Me!',
#   'employees': None,
#   'year': 2009,
#   'category': None,
#   'id': ObjectId('52cdef7e4bab8bd67529ad55'),
#   'money raised': '$0',
#   'city': '',
#   'country': 'USA',
#   'latitude': 37.755068,
#   'longitude': -122.418026,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.418026, 37.755068]}},
#  {'name': 'GrouperEye',
#   'employees': 3,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529adcf'),
#   'money raised': '$0',
#   'city': 'Washington',
#   'country': 'USA',
#   'latitude': 38.9169394,
#   'longitude': -77.0852258,
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0852258, 38.9169394]}},
#  {'name': 'MyFolio',
#   'employees': None,
#   'year': 2009,
#   'category': 'network_hosting',
#   'id': ObjectId('52cdef7e4bab8bd67529ae0f'),
#   'money raised': '$0',
#   'city': 'San Jose',
#   'country': 'USA',
#   'latitude': 37.317649,
#   'longitude': -121.948532,
#   'coordinates': {'type': 'Point', 'coordinates': [-121.948532, 37.317649]}},
#  {'name': 'Skilto',
#   'employees': 2,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7e4bab8bd67529ae15'),
#   'money raised': '$0',
#   'city': 'Brussels',
#   'country': 'BEL',
#   'latitude': 50.837051,
#   'longitude': 4.367612,
#   'coordinates': {'type': 'Point', 'coordinates': [4.367612, 50.837051]}},
#  {'name': 'ikywim creative',
#   'employees': 2,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529ae45'),
#   'money raised': '$0',
#   'city': 'Winter Park',
#   'country': 'USA',
#   'latitude': 28.621704,
#   'longitude': -81.290729,
#   'coordinates': {'type': 'Point', 'coordinates': [-81.290729, 28.621704]}},
#  {'name': 'iplotz',
#   'employees': 5,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7e4bab8bd67529ae4f'),
#   'money raised': '$0',
#   'city': 'Stephens City',
#   'country': 'USA',
#   'latitude': 39.0832204,
#   'longitude': -78.218254,
#   'coordinates': {'type': 'Point', 'coordinates': [-78.218254, 39.0832204]}},
#  {'name': 'Talari Networks',
#   'employees': 60,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529ae9f'),
#   'money raised': '$45.1M',
#   'city': 'San Jose',
#   'country': 'USA',
#   'latitude': 37.317735,
#   'longitude': -121.949417,
#   'coordinates': {'type': 'Point', 'coordinates': [-121.949417, 37.317735]}},
#  {'name': 'Talari Networks',
#   'employees': 60,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529ae9f'),
#   'money raised': '$45.1M',
#   'city': 'Morrisville',
#   'country': 'USA',
#   'latitude': 35.8535092,
#   'longitude': -78.8267112,
#   'coordinates': {'type': 'Point', 'coordinates': [-78.8267112, 35.8535092]}},
#  {'name': 'Zammr',
#   'employees': 1,
#   'year': 2009,
#   'category': 'network_hosting',
#   'id': ObjectId('52cdef7e4bab8bd67529af0b'),
#   'money raised': '$0',
#   'city': 'Holland',
#   'country': 'USA',
#   'latitude': 42.7904907,
#   'longitude': -86.0667227,
#   'coordinates': {'type': 'Point', 'coordinates': [-86.0667227, 42.7904907]}},
#  {'name': 'Shutl',
#   'employees': 10,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7e4bab8bd67529af1f'),
#   'money raised': '£7.66M',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5196135,
#   'longitude': -0.1020265,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1020265, 51.5196135]}},
#  {'name': 'Interacto',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529af21'),
#   'money raised': '$0',
#   'city': 'Heeze',
#   'country': 'NLD',
#   'latitude': 51.3673409,
#   'longitude': 5.5858466,
#   'coordinates': {'type': 'Point', 'coordinates': [5.5858466, 51.3673409]}},
#  {'name': 'Asurrent',
#   'employees': 3,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529af26'),
#   'money raised': '$0',
#   'city': 'Marietta',
#   'country': 'USA',
#   'latitude': 34.013247,
#   'longitude': -84.495636,
#   'coordinates': {'type': 'Point', 'coordinates': [-84.495636, 34.013247]}},
#  {'name': 'Ontology2',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529af49'),
#   'money raised': '$0',
#   'city': 'Brooktondale',
#   'country': 'USA',
#   'latitude': 42.362886,
#   'longitude': -76.356869,
#   'coordinates': {'type': 'Point', 'coordinates': [-76.356869, 42.362886]}},
#  {'name': 'Music For Busy People',
#   'employees': 3,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529af59'),
#   'money raised': '$0',
#   'city': 'New York City',
#   'country': 'USA',
#   'latitude': 40.727763,
#   'longitude': -73.976169,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.976169, 40.727763]}},
#  {'name': 'Centillion',
#   'employees': 5,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7e4bab8bd67529af76'),
#   'money raised': '$0',
#   'city': 'Split',
#   'country': 'HRV',
#   'latitude': 43.5141923,
#   'longitude': 16.4389264,
#   'coordinates': {'type': 'Point', 'coordinates': [16.4389264, 43.5141923]}},
#  {'name': 'alteregoweb',
#   'employees': 1,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529af77'),
#   'money raised': '$0',
#   'city': 'Figueres, Girona',
#   'country': 'ESP',
#   'latitude': 42.2674977,
#   'longitude': 2.9608395,
#   'coordinates': {'type': 'Point', 'coordinates': [2.9608395, 42.2674977]}},
#  {'name': 'Milabra',
#   'employees': None,
#   'year': 2009,
#   'category': None,
#   'id': ObjectId('52cdef7e4bab8bd67529af8e'),
#   'money raised': '$0',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.743616,
#   'longitude': -73.9880796,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9880796, 40.743616]}},
#  {'name': 'kinDragon',
#   'employees': 1,
#   'year': 2010,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529afbb'),
#   'money raised': '$0',
#   'city': 'Sarasota',
#   'country': 'USA',
#   'latitude': 27.4081935,
#   'longitude': -82.5294065,
#   'coordinates': {'type': 'Point', 'coordinates': [-82.5294065, 27.4081935]}},
#  {'name': 'VouChaCha',
#   'employees': 15,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7e4bab8bd67529b015'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5001524,
#   'longitude': -0.1262362,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1262362, 51.5001524]}},
#  {'name': 'CanvasGrafix',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b019'),
#   'money raised': '$0',
#   'city': 'St. Louis',
#   'country': 'USA',
#   'latitude': 38.675833,
#   'longitude': -90.482766,
#   'coordinates': {'type': 'Point', 'coordinates': [-90.482766, 38.675833]}},
#  {'name': 'Rouse Media',
#   'employees': 3,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7e4bab8bd67529b0ad'),
#   'money raised': '$0',
#   'city': 'Coventry',
#   'country': 'GBR',
#   'latitude': 52.4087359,
#   'longitude': -1.4761532,
#   'coordinates': {'type': 'Point', 'coordinates': [-1.4761532, 52.4087359]}},
#  {'name': 'Reflect7',
#   'employees': 3,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7e4bab8bd67529b0d1'),
#   'money raised': '$0',
#   'city': 'Lincoln',
#   'country': 'USA',
#   'latitude': 40.802858,
#   'longitude': -96.694751,
#   'coordinates': {'type': 'Point', 'coordinates': [-96.694751, 40.802858]}},
#  {'name': 'Tinychat',
#   'employees': 5,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b0f2'),
#   'money raised': '$1.5M',
#   'city': 'Glen Cove',
#   'country': 'USA',
#   'latitude': 42.3756409,
#   'longitude': -72.5196907,
#   'coordinates': {'type': 'Point', 'coordinates': [-72.5196907, 42.3756409]}},
#  {'name': 'Transifex',
#   'employees': 12,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529b100'),
#   'money raised': '$0',
#   'city': 'Menlo Park',
#   'country': 'USA',
#   'latitude': 37.4513629,
#   'longitude': -122.1842112,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.1842112, 37.4513629]}},
#  {'name': 'completelyprivatefiles',
#   'employees': 1,
#   'year': 2009,
#   'category': 'security',
#   'id': ObjectId('52cdef7e4bab8bd67529b108'),
#   'money raised': '$0',
#   'city': 'Nampa',
#   'country': 'USA',
#   'latitude': 43.5408,
#   'longitude': -116.5625,
#   'coordinates': {'type': 'Point', 'coordinates': [-116.5625, 43.5408]}},
#  {'name': 'BASH Gaming',
#   'employees': 25,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529b158'),
#   'money raised': '$1M',
#   'city': 'Fremont',
#   'country': 'USA',
#   'latitude': 37.5561712,
#   'longitude': -122.0780632,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.0780632, 37.5561712]}},
#  {'name': 'BASH Gaming',
#   'employees': 25,
#   'year': 2010,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7e4bab8bd67529b158'),
#   'money raised': '$1M',
#   'city': 'Bangalore',
#   'country': 'IND',
#   'latitude': 12.971606,
#   'longitude': 77.594376,
#   'coordinates': {'type': 'Point', 'coordinates': [77.594376, 12.971606]}},
#  {'name': 'Plupper',
#   'employees': 2,
#   'year': 2009,
#   'category': 'enterprise',
#   'id': ObjectId('52cdef7e4bab8bd67529b15b'),
#   'money raised': '$0',
#   'city': 'Prague',
#   'country': 'CZE',
#   'latitude': 50.0528269,
#   'longitude': 14.5120024,
#   'coordinates': {'type': 'Point', 'coordinates': [14.5120024, 50.0528269]}},
#  {'name': 'BidPlace SB',
#   'employees': 11,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b16f'),
#   'money raised': '$0',
#   'city': 'Baltimore',
#   'country': 'USA',
#   'latitude': 39.274034,
#   'longitude': -76.5908291,
#   'coordinates': {'type': 'Point', 'coordinates': [-76.5908291, 39.274034]}},
#  {'name': 'imFORZA Marketing',
#   'employees': 30,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b17c'),
#   'money raised': '$0',
#   'city': 'El Segundo',
#   'country': 'USA',
#   'latitude': 33.92854,
#   'longitude': -118.397818,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.397818, 33.92854]}},
#  {'name': 'IamStocks',
#   'employees': 1,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7e4bab8bd67529b1d5'),
#   'money raised': '$0',
#   'city': 'North Miami',
#   'country': 'USA',
#   'latitude': 25.8945858,
#   'longitude': -80.1622525,
#   'coordinates': {'type': 'Point', 'coordinates': [-80.1622525, 25.8945858]}},
#  {'name': 'Startup Revival',
#   'employees': 1,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7e4bab8bd67529b1ce'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.775196,
#   'longitude': -122.419204,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'name': 'CitySpur',
#   'employees': 17,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7e4bab8bd67529b1e4'),
#   'money raised': '$0',
#   'city': 'Scottsdale',
#   'country': 'USA',
#   'latitude': 33.487056,
#   'longitude': -111.909805,
#   'coordinates': {'type': 'Point', 'coordinates': [-111.909805, 33.487056]}},
#  {'name': 'AppNeta',
#   'employees': None,
#   'year': 2010,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529b1f6'),
#   'money raised': '$55.8M',
#   'city': 'SOUTH BOSTON',
#   'country': 'USA',
#   'latitude': 42.318138,
#   'longitude': -71.24756,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.24756, 42.318138]}},
#  {'name': 'GreenITers',
#   'employees': 4,
#   'year': 2009,
#   'category': 'cleantech',
#   'id': ObjectId('52cdef7e4bab8bd67529b208'),
#   'money raised': '$0',
#   'city': 'Tokyo',
#   'country': 'JPN',
#   'latitude': 37.443,
#   'longitude': -122.159291,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.159291, 37.443]}},
#  {'name': 'AppZero',
#   'employees': 50,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529b22a'),
#   'money raised': '$15.1M',
#   'city': 'Andover',
#   'country': 'USA',
#   'latitude': 42.6751888,
#   'longitude': -71.1469003,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.1469003, 42.6751888]}},
#  {'name': 'betterchange',
#   'employees': None,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7e4bab8bd67529b232'),
#   'money raised': '$0',
#   'city': 'GieÃŸen',
#   'country': 'DEU',
#   'latitude': 50.5777223,
#   'longitude': 8.675371,
#   'coordinates': {'type': 'Point', 'coordinates': [8.675371, 50.5777223]}},
#  {'name': 'PebbleForge',
#   'employees': 4,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529b23c'),
#   'money raised': '$0',
#   'city': 'KOCHI, KERALA',
#   'country': 'IND',
#   'latitude': 9.9396253,
#   'longitude': 76.2594981,
#   'coordinates': {'type': 'Point', 'coordinates': [76.2594981, 9.9396253]}},
#  {'name': 'TwitterCorp',
#   'employees': 1,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b23f'),
#   'money raised': '$0',
#   'city': 'College Place',
#   'country': 'USA',
#   'latitude': 46.0439,
#   'longitude': -118.378229,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.378229, 46.0439]}},
#  {'name': 'Action Sports Branding',
#   'employees': 3,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7e4bab8bd67529b261'),
#   'money raised': '$0',
#   'city': 'Boston',
#   'country': 'USA',
#   'latitude': 42.3983662,
#   'longitude': -71.0213788,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.0213788, 42.3983662]}},
#  {'name': 'RealUp',
#   'employees': None,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7e4bab8bd67529b266'),
#   'money raised': '$0',
#   'city': 'Raleigh',
#   'country': 'USA',
#   'latitude': 35.7892464,
#   'longitude': -78.7252479,
#   'coordinates': {'type': 'Point', 'coordinates': [-78.7252479, 35.7892464]}},
#  {'name': 'MyLikes',
#   'employees': None,
#   'year': 2010,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2a6'),
#   'money raised': '$6.23M',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.777995,
#   'longitude': -122.408914,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.408914, 37.777995]}},
#  {'name': 'Clasilistados',
#   'employees': 4,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2ab'),
#   'money raised': '$0',
#   'city': 'Belmont',
#   'country': 'USA',
#   'latitude': 37.515853,
#   'longitude': -122.3050823,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.3050823, 37.515853]}},
#  {'name': 'The Vertical Action Group',
#   'employees': 10,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7e4bab8bd67529b2b3'),
#   'money raised': '$0',
#   'city': 'San Francisco',
#   'country': 'USA',
#   'latitude': 37.7983181,
#   'longitude': -122.4000032,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.4000032, 37.7983181]}},
#  {'name': 'Cognitive Match',
#   'employees': 40,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2d9'),
#   'money raised': '$10.2M',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5119418,
#   'longitude': -0.0936688,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.0936688, 51.5119418]}},
#  {'name': 'Cognitive Match',
#   'employees': 40,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2d9'),
#   'money raised': '$10.2M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.7454098,
#   'longitude': -73.9822211,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9822211, 40.7454098]}},
#  {'name': 'Cognitive Match',
#   'employees': 40,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2d9'),
#   'money raised': '$10.2M',
#   'city': 'Palo Alto',
#   'country': 'USA',
#   'latitude': 37.380653,
#   'longitude': -122.1156934,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.1156934, 37.380653]}},
#  {'name': 'Cognitive Match',
#   'employees': 40,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2d9'),
#   'money raised': '$10.2M',
#   'city': 'Omaha',
#   'country': 'USA',
#   'latitude': 41.2601663,
#   'longitude': -96.0791435,
#   'coordinates': {'type': 'Point', 'coordinates': [-96.0791435, 41.2601663]}},
#  {'name': 'Simulmedia',
#   'employees': 35,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7e4bab8bd67529b2dc'),
#   'money raised': '$57.3M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.727216,
#   'longitude': -73.994797,
#   'coordinates': {'type': 'Point', 'coordinates': [-73.994797, 40.727216]}},
#  {'name': 'Tenant Txt',
#   'employees': None,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7e4bab8bd67529b2f0'),
#   'money raised': '$0',
#   'city': 'Houston',
#   'country': 'USA',
#   'latitude': 29.733947,
#   'longitude': -95.5393869,
#   'coordinates': {'type': 'Point', 'coordinates': [-95.5393869, 29.733947]}},
#  {'name': 'rent2friend',
#   'employees': 1,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b306'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5001524,
#   'longitude': -0.1262362,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1262362, 51.5001524]}},
#  {'name': 'Wolfram Alpha',
#   'employees': None,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b30a'),
#   'money raised': '$0',
#   'city': 'Champaign',
#   'country': 'USA',
#   'latitude': 40.097071,
#   'longitude': -88.245638,
#   'coordinates': {'type': 'Point', 'coordinates': [-88.245638, 40.097071]}},
#  {'name': 'Gridstore',
#   'employees': 31,
#   'year': 2009,
#   'category': 'network_hosting',
#   'id': ObjectId('52cdef7e4bab8bd67529b32d'),
#   'money raised': '€25M',
#   'city': 'Mountain View',
#   'country': 'USA',
#   'latitude': 37.4189073,
#   'longitude': -122.0884286,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.0884286, 37.4189073]}},
#  {'name': 'VitalLock',
#   'employees': 4,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7e4bab8bd67529b33c'),
#   'money raised': '$0',
#   'city': 'Cambridge',
#   'country': 'USA',
#   'latitude': 42.362856,
#   'longitude': -71.083762,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.083762, 42.362856]}},
#  {'name': 'OBE Pro',
#   'employees': 4,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7e4bab8bd67529b386'),
#   'money raised': '$0',
#   'city': 'Indian Harbour Beach',
#   'country': 'USA',
#   'latitude': 28.1524632,
#   'longitude': -80.5883964,
#   'coordinates': {'type': 'Point', 'coordinates': [-80.5883964, 28.1524632]}},
#  {'name': 'Internet Marketing Academy Australia',
#   'employees': 8,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7e4bab8bd67529b3ba'),
#   'money raised': '$100k',
#   'city': 'Melbourne',
#   'country': 'AUS',
# ...
#  {'name': 'Solix Biofuels',
#   'employees': 50,
#   'year': 2009,
#   'category': 'cleantech',
#   'id': ObjectId('52cdef7f4bab8bd67529c00e'),
#   'money raised': '$68.8M',
#   'city': 'Fort Collins',
#   'country': 'USA',
#   'latitude': 40.5932386,
#   'longitude': -105.0766501,
#   'coordinates': {'type': 'Point', 'coordinates': [-105.0766501, 40.5932386]}},
#  {'name': 'Ykone',
#   'employees': 10,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c014'),
#   'money raised': '€1.5M',
#   'city': 'Paris',
#   'country': 'FRA',
#   'latitude': 48.8566667,
#   'longitude': 2.3509871,
#   'coordinates': {'type': 'Point', 'coordinates': [2.3509871, 48.8566667]}},
#  {'name': 'youserbase',
#   'employees': 2,
#   'year': 2009,
#   'category': 'network_hosting',
#   'id': ObjectId('52cdef7f4bab8bd67529c025'),
#   'money raised': '$0',
#   'city': 'Oldenburg',
#   'country': 'DEU',
#   'latitude': 53.14967,
#   'longitude': 8.200653,
#   'coordinates': {'type': 'Point', 'coordinates': [8.200653, 53.14967]}},
#  {'name': 'OzTern Digital Services',
#   'employees': None,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7f4bab8bd67529c023'),
#   'money raised': '$0',
#   'city': 'Trivandrum',
#   'country': 'IND',
#   'latitude': 8.503696,
#   'longitude': 76.952187,
#   'coordinates': {'type': 'Point', 'coordinates': [76.952187, 8.503696]}},
#  {'name': 'Clovis Oncology',
#   'employees': None,
#   'year': 2009,
#   'category': 'biotech',
#   'id': ObjectId('52cdef7f4bab8bd67529c041'),
#   'money raised': '$357M',
#   'city': 'Boulder',
#   'country': 'USA',
#   'latitude': 40.026,
#   'longitude': -105.259041,
#   'coordinates': {'type': 'Point', 'coordinates': [-105.259041, 40.026]}},
#  {'name': 'ResuWe',
#   'employees': 5,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c048'),
#   'money raised': '$0',
#   'city': 'Laguna Beach',
#   'country': 'USA',
#   'latitude': 33.5341548,
#   'longitude': -117.7769669,
#   'coordinates': {'type': 'Point', 'coordinates': [-117.7769669, 33.5341548]}},
#  {'name': 'Startlike',
#   'employees': 8,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c052'),
#   'money raised': '$0',
#   'city': 'Columbia',
#   'country': 'USA',
#   'latitude': 34.002737,
#   'longitude': -81.018312,
#   'coordinates': {'type': 'Point', 'coordinates': [-81.018312, 34.002737]}},
#  {'name': 'ITTAGS',
#   'employees': None,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c071'),
#   'money raised': '$0',
#   'city': 'Los Angeles',
#   'country': 'USA',
#   'latitude': 34.052187,
#   'longitude': -118.243425,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'name': 'Ray Websmith',
#   'employees': None,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c07f'),
#   'money raised': '$0',
#   'city': 'Crystal Lake',
#   'country': 'USA',
#   'latitude': 42.2796339,
#   'longitude': -88.3339768,
#   'coordinates': {'type': 'Point', 'coordinates': [-88.3339768, 42.2796339]}},
#  {'name': 'Recreax',
#   'employees': 3,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7f4bab8bd67529c081'),
#   'money raised': '$0',
#   'city': 'Ham',
#   'country': 'BEL',
#   'latitude': 51.0966039,
#   'longitude': 5.1730329,
#   'coordinates': {'type': 'Point', 'coordinates': [5.1730329, 51.0966039]}},
#  {'name': 'Enternships',
#   'employees': 15,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c098'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5215279,
#   'longitude': -0.1038219,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1038219, 51.5215279]}},
#  {'name': 'Comufy',
#   'employees': None,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7f4bab8bd67529c0c6'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5220763,
#   'longitude': -0.1153003,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1153003, 51.5220763]}},
#  {'name': 'Kvittar',
#   'employees': 4,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c129'),
#   'money raised': '$0',
#   'city': 'Malmö',
#   'country': 'SWE',
#   'latitude': 55.6057989,
#   'longitude': 12.9950742,
#   'coordinates': {'type': 'Point', 'coordinates': [12.9950742, 55.6057989]}},
#  {'name': 'Layar',
#   'employees': 32,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c12a'),
#   'money raised': '$13.4M',
#   'city': 'Amsterdam',
#   'country': 'NLD',
#   'latitude': 52.3657578,
#   'longitude': 4.8928722,
#   'coordinates': {'type': 'Point', 'coordinates': [4.8928722, 52.3657578]}},
#  {'name': 'GatherSource',
#   'employees': None,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c132'),
#   'money raised': '$0',
#   'city': 'Grand Forks',
#   'country': 'USA',
#   'latitude': 47.909156,
#   'longitude': -97.055612,
#   'coordinates': {'type': 'Point', 'coordinates': [-97.055612, 47.909156]}},
#  {'name': 'PicFog',
#   'employees': 1,
#   'year': 2009,
#   'category': 'search',
#   'id': ObjectId('52cdef7f4bab8bd67529c14f'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.4770982,
#   'longitude': -0.2867703,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.2867703, 51.4770982]}},
#  {'name': 'Taxi Fares app',
#   'employees': 5,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c168'),
#   'money raised': '$0',
#   'city': 'Madrid',
#   'country': 'ESP',
#   'latitude': 40.4244585,
#   'longitude': -3.6990948,
#   'coordinates': {'type': 'Point', 'coordinates': [-3.6990948, 40.4244585]}},
#  {'name': 'Actinobac Biomed',
#   'employees': None,
#   'year': 2009,
#   'category': 'biotech',
#   'id': ObjectId('52cdef7f4bab8bd67529c176'),
#   'money raised': '$600k',
#   'city': 'North Brunswick',
#   'country': 'USA',
#   'latitude': 40.455501,
#   'longitude': -74.478931,
#   'coordinates': {'type': 'Point', 'coordinates': [-74.478931, 40.455501]}},
#  {'name': 'Lipperhey',
#   'employees': 6,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c1aa'),
#   'money raised': '€200k',
#   'city': 'Amsterdam',
#   'country': 'NLD',
#   'latitude': 52.3655578,
#   'longitude': 4.9345824,
#   'coordinates': {'type': 'Point', 'coordinates': [4.9345824, 52.3655578]}},
#  {'name': 'ticketea',
#   'employees': None,
#   'year': 2010,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7f4bab8bd67529c1a8'),
#   'money raised': '$5.73M',
#   'city': 'Madrid',
#   'country': 'ESP',
#   'latitude': 40.4455155,
#   'longitude': -3.7061764,
#   'coordinates': {'type': 'Point', 'coordinates': [-3.7061764, 40.4455155]}},
#  {'name': 'ZOOMcatalog',
#   'employees': 7,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7f4bab8bd67529c1ef'),
#   'money raised': '$0',
#   'city': 'Lafayette',
#   'country': 'USA',
#   'latitude': 40.003146,
#   'longitude': -105.137715,
#   'coordinates': {'type': 'Point', 'coordinates': [-105.137715, 40.003146]}},
#  {'name': 'Wikitude',
#   'employees': 20,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c1f5'),
#   'money raised': '$0',
#   'city': 'Salzburg',
#   'country': 'AUT',
#   'latitude': 47.8227,
#   'longitude': 13.041788,
#   'coordinates': {'type': 'Point', 'coordinates': [13.041788, 47.8227]}},
#  {'name': 'vooch',
#   'employees': None,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c1fa'),
#   'money raised': '$0',
#   'city': 'Tulln',
#   'country': 'AUT',
#   'latitude': 48.1154399,
#   'longitude': 16.2974355,
#   'coordinates': {'type': 'Point', 'coordinates': [16.2974355, 48.1154399]}},
#  {'name': 'Midwest Data Systems',
#   'employees': 8,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7f4bab8bd67529c232'),
#   'money raised': '$0',
#   'city': 'Marinette',
#   'country': 'USA',
#   'latitude': 45.0850398,
#   'longitude': -87.6329743,
#   'coordinates': {'type': 'Point', 'coordinates': [-87.6329743, 45.0850398]}},
#  {'name': 'Truckeo',
#   'employees': None,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7f4bab8bd67529c235'),
#   'money raised': '$0',
#   'city': 'Tucson',
#   'country': 'USA',
#   'latitude': 32.2306445,
#   'longitude': -110.9725175,
#   'coordinates': {'type': 'Point', 'coordinates': [-110.9725175, 32.2306445]}},
#  {'name': 'Vortimer',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c248'),
#   'money raised': '$0',
#   'city': 'Washington',
#   'country': 'USA',
#   'latitude': 38.905504,
#   'longitude': -77.05681,
#   'coordinates': {'type': 'Point', 'coordinates': [-77.05681, 38.905504]}},
#  {'name': 'Myhive',
#   'employees': 6,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c28c'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5514688,
#   'longitude': -0.1996418,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1996418, 51.5514688]}},
#  {'name': '140Ware',
#   'employees': 3,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c2c5'),
#   'money raised': '$0',
#   'city': 'Mayaguez',
#   'country': 'PRI',
#   'latitude': 18.2066344,
#   'longitude': -67.1517568,
#   'coordinates': {'type': 'Point', 'coordinates': [-67.1517568, 18.2066344]}},
#  {'name': 'Asyus',
#   'employees': 7,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c2c9'),
#   'money raised': '$0',
#   'city': 'Monte Sereno',
#   'country': 'USA',
#   'latitude': 37.241813,
#   'longitude': -121.986779,
#   'coordinates': {'type': 'Point', 'coordinates': [-121.986779, 37.241813]}},
#  {'name': 'Delphi',
#   'employees': None,
#   'year': 2009,
#   'category': 'cleantech',
#   'id': ObjectId('52cdef7f4bab8bd67529c2d0'),
#   'money raised': '$8M',
#   'city': '',
#   'country': 'USA',
#   'latitude': 42.603532,
#   'longitude': -83.16134,
#   'coordinates': {'type': 'Point', 'coordinates': [-83.16134, 42.603532]}},
#  {'name': 'Easter Egg',
#   'employees': None,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c2ec'),
#   'money raised': '$0',
#   'city': 'Milano',
#   'country': 'ITA',
#   'latitude': 45.4649519,
#   'longitude': 9.2087727,
#   'coordinates': {'type': 'Point', 'coordinates': [9.2087727, 45.4649519]}},
#  {'name': 'ChallengePost',
#   'employees': 17,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c343'),
#   'money raised': '$4.6M',
#   'city': 'New York',
#   'country': 'USA',
#   'latitude': 40.7408042,
#   'longitude': -74.00717,
#   'coordinates': {'type': 'Point', 'coordinates': [-74.00717, 40.7408042]}},
#  {'name': 'Outspoken Media',
#   'employees': 8,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7f4bab8bd67529c444'),
#   'money raised': '$0',
#   'city': 'Troy',
#   'country': 'USA',
#   'latitude': 28.490886,
#   'longitude': -82.540512,
#   'coordinates': {'type': 'Point', 'coordinates': [-82.540512, 28.490886]}},
#  {'name': 'Clickom',
#   'employees': 11,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7f4bab8bd67529c4b9'),
#   'money raised': '$0',
#   'city': 'Toronto, ON',
#   'country': 'CAN',
#   'latitude': 43.6502994,
#   'longitude': -79.3762688,
#   'coordinates': {'type': 'Point', 'coordinates': [-79.3762688, 43.6502994]}},
#  {'name': 'ftopia',
#   'employees': 7,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c520'),
#   'money raised': '$0',
#   'city': 'Paris',
#   'country': 'FRA',
#   'latitude': 53.3328144,
#   'longitude': -6.2493777,
#   'coordinates': {'type': 'Point', 'coordinates': [-6.2493777, 53.3328144]}},
#  {'name': 'Collective Core',
#   'employees': 1,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7f4bab8bd67529c52a'),
#   'money raised': '$0',
#   'city': 'Smyrna',
#   'country': 'USA',
#   'latitude': 33.8837,
#   'longitude': -84.5144,
#   'coordinates': {'type': 'Point', 'coordinates': [-84.5144, 33.8837]}},
#  {'name': 'Tiverias Apps',
#   'employees': 20,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c525'),
#   'money raised': '$0',
#   'city': 'Cambridge',
#   'country': 'USA',
#   'latitude': 42.3672873,
#   'longitude': -71.0814466,
#   'coordinates': {'type': 'Point', 'coordinates': [-71.0814466, 42.3672873]}},
#  {'name': 'Glacir',
#   'employees': 5,
#   'year': 2009,
#   'category': 'other',
#   'id': ObjectId('52cdef7f4bab8bd67529c52b'),
#   'money raised': '$0',
#   'city': 'Columbus',
#   'country': 'USA',
#   'latitude': 39.977726,
#   'longitude': -83.01143,
#   'coordinates': {'type': 'Point', 'coordinates': [-83.01143, 39.977726]}},
#  {'name': 'HOTForms123',
#   'employees': 2,
#   'year': 2009,
#   'category': 'web',
#   'id': ObjectId('52cdef7f4bab8bd67529c533'),
#   'money raised': '$0',
#   'city': 'Beverly Hills',
#   'country': 'USA',
#   'latitude': 34.0698912,
#   'longitude': -118.405325,
#   'coordinates': {'type': 'Point', 'coordinates': [-118.405325, 34.0698912]}},
#  {'name': 'pTracker',
#   'employees': 2,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c5de'),
#   'money raised': '$0',
#   'city': 'Austin',
#   'country': 'USA',
#   'latitude': 30.268735,
#   'longitude': -97.745209,
#   'coordinates': {'type': 'Point', 'coordinates': [-97.745209, 30.268735]}},
#  {'name': 'Bookwhen',
#   'employees': 2,
#   'year': 2009,
#   'category': 'ecommerce',
#   'id': ObjectId('52cdef7f4bab8bd67529c5dd'),
#   'money raised': '$0',
#   'city': 'Oxford',
#   'country': 'GBR',
#   'latitude': 51.7714264,
#   'longitude': -1.2581049,
#   'coordinates': {'type': 'Point', 'coordinates': [-1.2581049, 51.7714264]}},
#  {'name': 'Tiny Speck',
#   'employees': 45,
#   'year': 2009,
#   'category': 'games_video',
#   'id': ObjectId('52cdef7f4bab8bd67529c6b6'),
#   'money raised': '$17.2M',
#   'city': 'Vancouver',
#   'country': 'CAN',
#   'latitude': 49.2824551,
#   'longitude': -123.109217,
#   'coordinates': {'type': 'Point', 'coordinates': [-123.109217, 49.2824551]}},
#  {'name': 'SEO Sumo',
#   'employees': 5,
#   'year': 2009,
#   'category': 'public_relations',
#   'id': ObjectId('52cdef7f4bab8bd67529c6d5'),
#   'money raised': '$0',
#   'city': 'Miami',
#   'country': 'USA',
#   'latitude': 25.723408,
#   'longitude': -80.306331,
#   'coordinates': {'type': 'Point', 'coordinates': [-80.306331, 25.723408]}},
#  {'name': 'InstantQ',
#   'employees': 3,
#   'year': 2009,
#   'category': 'advertising',
#   'id': ObjectId('52cdef7f4bab8bd67529c6d6'),
#   'money raised': '$0',
#   'city': 'Sunnyvale',
#   'country': 'USA',
#   'latitude': 37.369195,
#   'longitude': -122.036849,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.036849, 37.369195]}},
#  {'name': 'acrossair',
#   'employees': 6,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c6dc'),
#   'money raised': '$0',
#   'city': 'London',
#   'country': 'GBR',
#   'latitude': 51.5177425,
#   'longitude': -0.1165365,
#   'coordinates': {'type': 'Point', 'coordinates': [-0.1165365, 51.5177425]}},
#  {'name': 'MyChances',
#   'employees': 2,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7f4bab8bd67529c6e2'),
#   'money raised': '$0',
#   'city': 'Reno',
#   'country': 'USA',
#   'latitude': 39.394564,
#   'longitude': -119.8120795,
#   'coordinates': {'type': 'Point', 'coordinates': [-119.8120795, 39.394564]}},
#  {'name': 'MyChances',
#   'employees': 2,
#   'year': 2009,
#   'category': 'consulting',
#   'id': ObjectId('52cdef7f4bab8bd67529c6e2'),
#   'money raised': '$0',
#   'city': 'Menlo Park',
#   'country': 'USA',
#   'latitude': 37.4484914,
#   'longitude': -122.1802812,
#   'coordinates': {'type': 'Point', 'coordinates': [-122.1802812, 37.4484914]}},
#  {'name': 'Getyoo',
#   'employees': 10,
#   'year': 2009,
#   'category': 'mobile',
#   'id': ObjectId('52cdef7f4bab8bd67529c6e4'),
#   'money raised': '€1.13M',
#   'city': 'Brussels',
#   'country': 'BEL',
#   'latitude': 50.83997,
#   'longitude': 4.3464721,
#   'coordinates': {'type': 'Point', 'coordinates': [4.3464721, 50.83997]}},
#  {'name': 'Oriact',
#   'employees': None,
#   'year': 2009,
#   'category': 'software',
#   'id': ObjectId('52cdef7f4bab8bd67529c6f5'),
#   'money raised': '$0',
#   'city': 'KÃ¼ssnacht',
#   'country': 'CHE',
#   'latitude': 47.0882193,
#   'longitude': 8.4371634,
#   'coordinates': {'type': 'Point', 'coordinates': [8.4371634, 47.0882193]}}]

# %%
data = pd.DataFrame(prepareData(offices))

# %%
data.head()
# Out:
#        name  employees  year     category                        id  \
# 0  Mokitown        NaN  2011          web  52cdef7c4bab8bd675297ea7
# 1   PeekYou       20.0  2012       search  52cdef7c4bab8bd675297f94
# 2     GENWI       25.0  2010       mobile  52cdef7c4bab8bd675297f9e
# 3     Fixya       30.0  2013          web  52cdef7c4bab8bd675297fec
# 4     alluc        7.0  2009  games_video  52cdef7c4bab8bd675298038
#
#   money raised         city country   latitude   longitude  \
# 0           $0         None     USA  37.090240  -95.712891
# 1       $1.83M     New York     USA  40.757929  -73.985506
# 2        $7.1M    Los Altos     USA  33.817100 -111.903500
# 3          $8M    San Mateo     USA  37.566879 -122.323895
# 4           $0  Norderstedt     DEU  53.707739   10.023246
#
#                                          coordinates
# 0  {'type': 'Point', 'coordinates': [-95.712891, ...
# 1  {'type': 'Point', 'coordinates': [-73.985506, ...
# 2  {'type': 'Point', 'coordinates': [-111.9035, 3...
# 3  {'type': 'Point', 'coordinates': [-122.323895,...
# 4  {'type': 'Point', 'coordinates': [10.023246, 5...

# %%
data.dtypes
# Out:
# name             object
# employees       float64
# year              int64
# category         object
# id               object
# money raised     object
# city             object
# country          object
# latitude        float64
# longitude       float64
# coordinates      object
# dtype: object

# %%
def money_clean(data):
    
    ''' Function to convert money raised to int '''
    
    data['money raised']= data['money raised'].replace('[Kk]', '*100',regex = True).replace( 'M', '*1000000',regex=True)
    data['money raised']= data['money raised'].replace('[€$£]','',regex=True)
    #data['money raised']= data['money raised'].apply(np.int64)
    data['money raised']= data['money raised'].map(pd.eval)
    #data=data[data!=0].dropna()
    return money_comp

def category(data):
    
    ''' Function to clean category column '''
    
    web_design = {'search': 'web','mobile': 'web','web': 'web','games_video': 'web','ecommerce': 'web','advertising': 'web',
              'hardware': 'web','enterprise': 'web','network_hosting': 'web','software': 'web',
              'analytics': 'web','cleantech': 'web'}
    data = money_clean(data).replace(web_design, regex=True)
    return money_comp

# %%
data_new = category(data)

# %%
data_new
# Out:
#               name  employees  year category                        id  \
# 3            Fixya       30.0  2013      web  52cdef7c4bab8bd675297fec
# 21   BrandYourself       22.0  2009      web  52cdef7d4bab8bd675298ce2
# 56      Formspring       19.0  2009      web  52cdef7d4bab8bd67529a00e
# 58           Yipit       23.0  2010      web  52cdef7d4bab8bd67529a1e3
# 112       Tinychat        5.0  2009      web  52cdef7e4bab8bd67529b0f2
# 164         Tongal        8.0  2009      web  52cdef7e4bab8bd67529b572
# 295          Ykone       10.0  2009      web  52cdef7f4bab8bd67529c014
# 325  ChallengePost       17.0  2009      web  52cdef7f4bab8bd67529c343
#
#      money raised           city country   latitude   longitude  \
# 3       8000000.0      San Mateo     USA  37.566879 -122.323895
# 21      1500000.0       New York     USA  42.275263  -71.247620
# 56     14300000.0  San Francisco     USA  39.905226  -86.054702
# 58      7550000.0       New York     USA  40.744618  -73.987764
# 112     1500000.0      Glen Cove     USA  42.375641  -72.519691
# 164    16000000.0   Santa Monica     USA  34.007112 -118.489748
# 295     1500000.0          Paris     FRA  48.856667    2.350987
# 325     4600000.0       New York     USA  40.740804  -74.007170
#
#                                            coordinates
# 3    {'type': 'Point', 'coordinates': [-122.323895,...
# 21   {'type': 'Point', 'coordinates': [-71.24762, 4...
# 56   {'type': 'Point', 'coordinates': [-86.0547016,...
# 58   {'type': 'Point', 'coordinates': [-73.987764, ...
# 112  {'type': 'Point', 'coordinates': [-72.5196907,...
# 164  {'type': 'Point', 'coordinates': [-118.489748,...
# 295  {'type': 'Point', 'coordinates': [2.3509871, 4...
# 325  {'type': 'Point', 'coordinates': [-74.00717, 4...
